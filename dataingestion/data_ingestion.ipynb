# %%
dbutils.fs.mkdirs("dbfs:/FileStore/tables/sahan_project")
dbutils.fs.mkdirs("dbfs:/FileStore/tables/sahan_project/raw")
dbutils.fs.mkdirs("dbfs:/FileStore/tables/sahan_project/checkpoint")
# Out:
# True

# %%
dbutils.fs.mkdirs("dbfs:/FileStore/tables/sahan_project/bronze")
dbutils.fs.mkdirs("dbfs:/FileStore/tables/sahan_project/bronze/batch_data")
dbutils.fs.mkdirs("dbfs:/FileStore/tables/sahan_project/bronze/streaming_data")
# Out:
# True

# %%
dbutils.fs.mkdirs("dbfs:/FileStore/tables/sahan_project/silver")
dbutils.fs.mkdirs("dbfs:/FileStore/tables/sahan_project/silver/flights")
dbutils.fs.mkdirs("dbfs:/FileStore/tables/sahan_project/silver/airports")
dbutils.fs.mkdirs("dbfs:/FileStore/tables/sahan_project/silver/airlines")
# Out:
# True

# %%
dbutils.fs.mkdirs("dbfs:/FileStore/tables/sahan_project/gold")
dbutils.fs.mkdirs("/FileStore/tables/sahan_project/gold/flight_fact")
dbutils.fs.mkdirs("/FileStore/tables/sahan_project/gold/airline_dim_scd")
dbutils.fs.mkdirs("/FileStore/tables/sahan_project/gold/airport_dim")
# Out:
# True

# %%
dbutils.fs.ls("dbfs:/FileStore/tables/sahan_project")
# Out:
# [FileInfo(path='dbfs:/FileStore/tables/sahan_project/bronze/', name='bronze/', size=0, modificationTime=1766992160000),
#  FileInfo(path='dbfs:/FileStore/tables/sahan_project/checkpoint/', name='checkpoint/', size=0, modificationTime=1767089391000),
#  FileInfo(path='dbfs:/FileStore/tables/sahan_project/gold/', name='gold/', size=0, modificationTime=1767012308000),
#  FileInfo(path='dbfs:/FileStore/tables/sahan_project/raw/', name='raw/', size=0, modificationTime=1766992130000),
#  FileInfo(path='dbfs:/FileStore/tables/sahan_project/silver/', name='silver/', size=0, modificationTime=1767012298000)]
